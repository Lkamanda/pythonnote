# %%
# 类似于栈的先进后出
#　１．递推关系
#  2.要有临界值,如果没有则会造成栈溢出.
def digui(num):
    print(num)
    if num > 0:
        ＃这里用的是调用本身的函数
        digui(num-1)
    else:
        print('='*20)
    print(num)

digui(4)
# Out:
# 4
# 3
# 2
# 1
# 0
# ====================
# 0
# 1
# 2
# 3
# 4

# %%
# 汉诺塔 
# 3 个 7步

i = 0
def move(n,a,b,c):
    # 把变量全局化
    global i
    if n==1:
        i += 1
        print('移动第',i,'次',a,'->',c)
    else:
        move(n-1,a,c,b)
        move(1,a,b,c)
        move(n-1,b,a,c)
move(3,'A','B','C')
# Out:
# 移动第 1 次 A -> C
# 移动第 2 次 A -> B
# 移动第 3 次 C -> B
# 移动第 4 次 A -> C
# 移动第 5 次 B -> A
# 移动第 6 次 B -> C
# 移动第 7 次 A -> C

# %%
i = 0
def a():
    # 为定义 i 为全局变量 如果不定义只能访问不能操作
    # global i
    i += 1
    print(i)
a()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-19-ab2e991d8bb4> in <module>()
#       5     i += 1
#       6     print(i)
# ----> 7 a()
#
# <ipython-input-19-ab2e991d8bb4> in a()
#       3     # 为定义 i 为全局变量 如果不定义只能访问不能操作
#       4     # global i
# ----> 5     i += 1
#       6     print(i)
#       7 a()
#
# UnboundLocalError: local variable 'i' referenced before assignment

# %%
i = 0
def a():
    
    global i
    i += 1
    print(i)
a()
# Out:
# 1

# %%
import os

def getdirpath(dirpath):
    total = 0 
    # 获取所有文件
    allname = os.listdir(dirpath)
    for name in allname:
            # 拼接成完整路径
        fullpath=os.path.join(dirpath,name)
        # 判断是否是文件
        if os.path.isfile(fullpath):
            #　获取文件大小
            total += os.path.getsize(fullpath)
            # 判断是否为文件夹
        elif os.path.isdir(fullpath):
            # 如果是文件夹　，则调用自身 (递归 )
            total += getdirpath(fullpath)
    #　返回大小　
    return total
    
size = getdirpath(r'/home/tlxy/pythonnote')
print(size)
# Out:
# 860271

# %%
# 汉诺塔　
# 如果有n个盘 ,所有移动的步数为2^n-1 
i = 0 
# 定义一个函数给4个参数 ,n 为圆盘的个数,a代表A柱子
def move(n,a,b,c):
    global i 
    if n ==1: 
        i += 1
        print('移动了',i,'次',a,'->',c)
    else:
        # 把柱子A上的n-1个圆盘移动到B柱子上
        move(n-1,a,c,b)
        # 把柱子 A上最大的柱子移动到C上
        move(n,a,b,c)
        # 把柱子B上的n-1个圆盘借助A移动到B上
        move(n-1,b,a,c)
move(3,'A','B','C')
# Out:
# 移动了 1 次 A -> C
# 移动了 2 次 A -> C
# 移动了 3 次 A -> C
# 移动了 4 次 A -> C
# 移动了 5 次 A -> C
# 移动了 6 次 A -> C
# 移动了 7 次 A -> C
# 移动了 8 次 A -> C
# 移动了 9 次 A -> C
# 移动了 10 次 A -> C
# 移动了 11 次 A -> C
# 移动了 12 次 A -> C
# 移动了 13 次 A -> C
# 移动了 14 次 A -> C
# 移动了 15 次 A -> C
# 移动了 16 次 A -> C
# 移动了 17 次 A -> C
# 移动了 18 次 A -> C
# 移动了 19 次 A -> C
# 移动了 20 次 A -> C
# 移动了 21 次 A -> C
# 移动了 22 次 A -> C
# 移动了 23 次 A -> C
# 移动了 24 次 A -> C
# 移动了 25 次 A -> C
# 移动了 26 次 A -> C
# 移动了 27 次 A -> C
# 移动了 28 次 A -> C
# 移动了 29 次 A -> C
# 移动了 30 次 A -> C
# 移动了 31 次 A -> C
# 移动了 32 次 A -> C
# 移动了 33 次 A -> C
# 移动了 34 次 A -> C
# 移动了 35 次 A -> C
# 移动了 36 次 A -> C
# 移动了 37 次 A -> C
# 移动了 38 次 A -> C
# 移动了 39 次 A -> C
# 移动了 40 次 A -> C
# 移动了 41 次 A -> C
# 移动了 42 次 A -> C
# 移动了 43 次 A -> C
# 移动了 44 次 A -> C
# 移动了 45 次 A -> C
# 移动了 46 次 A -> C
# 移动了 47 次 A -> C
# 移动了 48 次 A -> C
# 移动了 49 次 A -> C
# 移动了 50 次 A -> C
# 移动了 51 次 A -> C
# 移动了 52 次 A -> C
# 移动了 53 次 A -> C
# 移动了 54 次 A -> C
# 移动了 55 次 A -> C
# 移动了 56 次 A -> C
# 移动了 57 次 A -> C
# 移动了 58 次 A -> C
# 移动了 59 次 A -> C
# 移动了 60 次 A -> C
# 移动了 61 次 A -> C
# 移动了 62 次 A -> C
# 移动了 63 次 A -> C
# 移动了 64 次 A -> C
# 移动了 65 次 A -> C
# 移动了 66 次 A -> C
# 移动了 67 次 A -> C
# 移动了 68 次 A -> C
# 移动了 69 次 A -> C
# 移动了 70 次 A -> C
# 移动了 71 次 A -> C
# 移动了 72 次 A -> C
# 移动了 73 次 A -> C
# 移动了 74 次 A -> C
# 移动了 75 次 A -> C
# 移动了 76 次 A -> C
# 移动了 77 次 A -> C
# 移动了 78 次 A -> C
# 移动了 79 次 A -> C
# 移动了 80 次 A -> C
# 移动了 81 次 A -> C
# 移动了 82 次 A -> C
# 移动了 83 次 A -> C
# 移动了 84 次 A -> C
# 移动了 85 次 A -> C
# 移动了 86 次 A -> C
# 移动了 87 次 A -> C
# 移动了 88 次 A -> C
# 移动了 89 次 A -> C
# 移动了 90 次 A -> C
# 移动了 91 次 A -> C
# 移动了 92 次 A -> C
# 移动了 93 次 A -> C
# 移动了 94 次 A -> C
# 移动了 95 次 A -> C
# 移动了 96 次 A -> C
# 移动了 97 次 A -> C
# 移动了 98 次 A -> C
# 移动了 99 次 A -> C
# 移动了 100 次 A -> C
# 移动了 101 次 A -> C
# 移动了 102 次 A -> C
# 移动了 103 次 A -> C
# 移动了 104 次 A -> C
# 移动了 105 次 A -> C
# 移动了 106 次 A -> C
# 移动了 107 次 A -> C
# 移动了 108 次 A -> C
# 移动了 109 次 A -> C
# 移动了 110 次 A -> C
# 移动了 111 次 A -> C
# 移动了 112 次 A -> C
# 移动了 113 次 A -> C
# 移动了 114 次 A -> C
# 移动了 115 次 A -> C
# 移动了 116 次 A -> C
# 移动了 117 次 A -> C
# 移动了 118 次 A -> C
# 移动了 119 次 A -> C
# 移动了 120 次 A -> C
# 移动了 121 次 A -> C
# 移动了 122 次 A -> C
# 移动了 123 次 A -> C
# 移动了 124 次 A -> C
# 移动了 125 次 A -> C
# 移动了 126 次 A -> C
# 移动了 127 次 A -> C
# 移动了 128 次 A -> C
# 移动了 129 次 A -> C
# 移动了 130 次 A -> C
# 移动了 131 次 A -> C
# 移动了 132 次 A -> C
# 移动了 133 次 A -> C
# 移动了 134 次 A -> C
# 移动了 135 次 A -> C
# 移动了 136 次 A -> C
# 移动了 137 次 A -> C
# 移动了 138 次 A -> C
# 移动了 139 次 A -> C
# 移动了 140 次 A -> C
# 移动了 141 次 A -> C
# 移动了 142 次 A -> C
# 移动了 143 次 A -> C
# 移动了 144 次 A -> C
# 移动了 145 次 A -> C
# 移动了 146 次 A -> C
# 移动了 147 次 A -> C
# 移动了 148 次 A -> C
# 移动了 149 次 A -> C
# 移动了 150 次 A -> C
# 移动了 151 次 A -> C
# 移动了 152 次 A -> C
# 移动了 153 次 A -> C
# 移动了 154 次 A -> C
# 移动了 155 次 A -> C
# 移动了 156 次 A -> C
# 移动了 157 次 A -> C
# 移动了 158 次 A -> C
# 移动了 159 次 A -> C
# 移动了 160 次 A -> C
# 移动了 161 次 A -> C
# 移动了 162 次 A -> C
# 移动了 163 次 A -> C
# 移动了 164 次 A -> C
# 移动了 165 次 A -> C
# 移动了 166 次 A -> C
# 移动了 167 次 A -> C
# 移动了 168 次 A -> C
# 移动了 169 次 A -> C
# 移动了 170 次 A -> C
# 移动了 171 次 A -> C
# 移动了 172 次 A -> C
# 移动了 173 次 A -> C
# 移动了 174 次 A -> C
# 移动了 175 次 A -> C
# 移动了 176 次 A -> C
# 移动了 177 次 A -> C
# 移动了 178 次 A -> C
# 移动了 179 次 A -> C
# 移动了 180 次 A -> C
# 移动了 181 次 A -> C
# 移动了 182 次 A -> C
# 移动了 183 次 A -> C
# 移动了 184 次 A -> C
# 移动了 185 次 A -> C
# 移动了 186 次 A -> C
# 移动了 187 次 A -> C
# 移动了 188 次 A -> C
# 移动了 189 次 A -> C
# 移动了 190 次 A -> C
# 移动了 191 次 A -> C
# 移动了 192 次 A -> C
# 移动了 193 次 A -> C
# 移动了 194 次 A -> C
# 移动了 195 次 A -> C
# 移动了 196 次 A -> C
# 移动了 197 次 A -> C
# 移动了 198 次 A -> C
# 移动了 199 次 A -> C
# 移动了 200 次 A -> C
# 移动了 201 次 A -> C
# 移动了 202 次 A -> C
# 移动了 203 次 A -> C
# 移动了 204 次 A -> C
# 移动了 205 次 A -> C
# 移动了 206 次 A -> C
# 移动了 207 次 A -> C
# 移动了 208 次 A -> C
# 移动了 209 次 A -> C
# 移动了 210 次 A -> C
# 移动了 211 次 A -> C
# 移动了 212 次 A -> C
# 移动了 213 次 A -> C
# 移动了 214 次 A -> C
# 移动了 215 次 A -> C
# 移动了 216 次 A -> C
# 移动了 217 次 A -> C
# 移动了 218 次 A -> C
# 移动了 219 次 A -> C
# 移动了 220 次 A -> C
# 移动了 221 次 A -> C
# 移动了 222 次 A -> C
# 移动了 223 次 A -> C
# 移动了 224 次 A -> C
# 移动了 225 次 A -> C
# 移动了 226 次 A -> C
# 移动了 227 次 A -> C
# 移动了 228 次 A -> C
# 移动了 229 次 A -> C
# 移动了 230 次 A -> C
# 移动了 231 次 A -> C
# 移动了 232 次 A -> C
# 移动了 233 次 A -> C
# 移动了 234 次 A -> C
# 移动了 235 次 A -> C
# 移动了 236 次 A -> C
# 移动了 237 次 A -> C
# 移动了 238 次 A -> C
# 移动了 239 次 A -> C
# 移动了 240 次 A -> C
# 移动了 241 次 A -> C
# 移动了 242 次 A -> C
# 移动了 243 次 A -> C
# 移动了 244 次 A -> C
# 移动了 245 次 A -> C
# 移动了 246 次 A -> C
# 移动了 247 次 A -> C
# 移动了 248 次 A -> C
# 移动了 249 次 A -> C
# 移动了 250 次 A -> C
# 移动了 251 次 A -> C
# 移动了 252 次 A -> C
# 移动了 253 次 A -> C
# 移动了 254 次 A -> C
# 移动了 255 次 A -> C
# 移动了 256 次 A -> C
# 移动了 257 次 A -> C
# 移动了 258 次 A -> C
# 移动了 259 次 A -> C
# 移动了 260 次 A -> C
# 移动了 261 次 A -> C
# 移动了 262 次 A -> C
# 移动了 263 次 A -> C
# 移动了 264 次 A -> C
# 移动了 265 次 A -> C
# 移动了 266 次 A -> C
# 移动了 267 次 A -> C
# 移动了 268 次 A -> C
# 移动了 269 次 A -> C
# 移动了 270 次 A -> C
# 移动了 271 次 A -> C
# 移动了 272 次 A -> C
# 移动了 273 次 A -> C
# 移动了 274 次 A -> C
# 移动了 275 次 A -> C
# 移动了 276 次 A -> C
# 移动了 277 次 A -> C
# 移动了 278 次 A -> C
# 移动了 279 次 A -> C
# 移动了 280 次 A -> C
# 移动了 281 次 A -> C
# 移动了 282 次 A -> C
# 移动了 283 次 A -> C
# 移动了 284 次 A -> C
# 移动了 285 次 A -> C
# 移动了 286 次 A -> C
# 移动了 287 次 A -> C
# 移动了 288 次 A -> C
# 移动了 289 次 A -> C
# 移动了 290 次 A -> C
# 移动了 291 次 A -> C
# 移动了 292 次 A -> C
# 移动了 293 次 A -> C
# 移动了 294 次 A -> C
# 移动了 295 次 A -> C
# 移动了 296 次 A -> C
# 移动了 297 次 A -> C
# 移动了 298 次 A -> C
# 移动了 299 次 A -> C
# 移动了 300 次 A -> C
# 移动了 301 次 A -> C
# 移动了 302 次 A -> C
# 移动了 303 次 A -> C
# 移动了 304 次 A -> C
# 移动了 305 次 A -> C
# 移动了 306 次 A -> C
# 移动了 307 次 A -> C
# 移动了 308 次 A -> C
# 移动了 309 次 A -> C
# 移动了 310 次 A -> C
# 移动了 311 次 A -> C
# 移动了 312 次 A -> C
# 移动了 313 次 A -> C
# 移动了 314 次 A -> C
# 移动了 315 次 A -> C
# 移动了 316 次 A -> C
# 移动了 317 次 A -> C
# 移动了 318 次 A -> C
# 移动了 319 次 A -> C
# 移动了 320 次 A -> C
# 移动了 321 次 A -> C
# 移动了 322 次 A -> C
# 移动了 323 次 A -> C
# 移动了 324 次 A -> C
# 移动了 325 次 A -> C
# 移动了 326 次 A -> C
# 移动了 327 次 A -> C
# 移动了 328 次 A -> C
# 移动了 329 次 A -> C
# 移动了 330 次 A -> C
# 移动了 331 次 A -> C
# 移动了 332 次 A -> C
# 移动了 333 次 A -> C
# 移动了 334 次 A -> C
# 移动了 335 次 A -> C
# 移动了 336 次 A -> C
# 移动了 337 次 A -> C
# 移动了 338 次 A -> C
# 移动了 339 次 A -> C
# 移动了 340 次 A -> C
# 移动了 341 次 A -> C
# 移动了 342 次 A -> C
# 移动了 343 次 A -> C
# 移动了 344 次 A -> C
# 移动了 345 次 A -> C
# 移动了 346 次 A -> C
# 移动了 347 次 A -> C
# 移动了 348 次 A -> C
# 移动了 349 次 A -> C
# 移动了 350 次 A -> C
# 移动了 351 次 A -> C
# 移动了 352 次 A -> C
# 移动了 353 次 A -> C
# 移动了 354 次 A -> C
# 移动了 355 次 A -> C
# 移动了 356 次 A -> C
# 移动了 357 次 A -> C
# 移动了 358 次 A -> C
# 移动了 359 次 A -> C
# 移动了 360 次 A -> C
# 移动了 361 次 A -> C
# 移动了 362 次 A -> C
# 移动了 363 次 A -> C
# 移动了 364 次 A -> C
# 移动了 365 次 A -> C
# 移动了 366 次 A -> C
# 移动了 367 次 A -> C
# 移动了 368 次 A -> C
# 移动了 369 次 A -> C
# 移动了 370 次 A -> C
# 移动了 371 次 A -> C
# 移动了 372 次 A -> C
# 移动了 373 次 A -> C
# 移动了 374 次 A -> C
# 移动了 375 次 A -> C
# 移动了 376 次 A -> C
# 移动了 377 次 A -> C
# 移动了 378 次 A -> C
# 移动了 379 次 A -> C
# 移动了 380 次 A -> C
# 移动了 381 次 A -> C
# 移动了 382 次 A -> C
# 移动了 383 次 A -> C
# 移动了 384 次 A -> C
# 移动了 385 次 A -> C
# 移动了 386 次 A -> C
# 移动了 387 次 A -> C
# 移动了 388 次 A -> C
# 移动了 389 次 A -> C
# 移动了 390 次 A -> C
# 移动了 391 次 A -> C
# 移动了 392 次 A -> C
# 移动了 393 次 A -> C
# 移动了 394 次 A -> C
# 移动了 395 次 A -> C
# 移动了 396 次 A -> C
# 移动了 397 次 A -> C
# 移动了 398 次 A -> C
# 移动了 399 次 A -> C
# 移动了 400 次 A -> C
# 移动了 401 次 A -> C
# 移动了 402 次 A -> C
# 移动了 403 次 A -> C
# 移动了 404 次 A -> C
# 移动了 405 次 A -> C
# 移动了 406 次 A -> C
# 移动了 407 次 A -> C
# 移动了 408 次 A -> C
# 移动了 409 次 A -> C
# 移动了 410 次 A -> C
# 移动了 411 次 A -> C
# 移动了 412 次 A -> C
# 移动了 413 次 A -> C
# 移动了 414 次 A -> C
# 移动了 415 次 A -> C
# 移动了 416 次 A -> C
# 移动了 417 次 A -> C
# 移动了 418 次 A -> C
# 移动了 419 次 A -> C
# 移动了 420 次 A -> C
# 移动了 421 次 A -> C
# 移动了 422 次 A -> C
# 移动了 423 次 A -> C
# 移动了 424 次 A -> C
# 移动了 425 次 A -> C
# 移动了 426 次 A -> C
# 移动了 427 次 A -> C
# 移动了 428 次 A -> C
# 移动了 429 次 A -> C
# 移动了 430 次 A -> C
# 移动了 431 次 A -> C
# 移动了 432 次 A -> C
# 移动了 433 次 A -> C
# 移动了 434 次 A -> C
# 移动了 435 次 A -> C
# 移动了 436 次 A -> C
# 移动了 437 次 A -> C
# 移动了 438 次 A -> C
# 移动了 439 次 A -> C
# 移动了 440 次 A -> C
# 移动了 441 次 A -> C
# 移动了 442 次 A -> C
# 移动了 443 次 A -> C
# 移动了 444 次 A -> C
# 移动了 445 次 A -> C
# 移动了 446 次 A -> C
# 移动了 447 次 A -> C
# 移动了 448 次 A -> C
# 移动了 449 次 A -> C
# 移动了 450 次 A -> C
# 移动了 451 次 A -> C
# 移动了 452 次 A -> C
# 移动了 453 次 A -> C
# 移动了 454 次 A -> C
# 移动了 455 次 A -> C
# 移动了 456 次 A -> C
# 移动了 457 次 A -> C
# 移动了 458 次 A -> C
# 移动了 459 次 A -> C
# 移动了 460 次 A -> C
# 移动了 461 次 A -> C
# 移动了 462 次 A -> C
# 移动了 463 次 A -> C
# 移动了 464 次 A -> C
# 移动了 465 次 A -> C
# 移动了 466 次 A -> C
# 移动了 467 次 A -> C
# 移动了 468 次 A -> C
# 移动了 469 次 A -> C
# 移动了 470 次 A -> C
# 移动了 471 次 A -> C
# 移动了 472 次 A -> C
# 移动了 473 次 A -> C
# 移动了 474 次 A -> C
# 移动了 475 次 A -> C
# 移动了 476 次 A -> C
# 移动了 477 次 A -> C
# 移动了 478 次 A -> C
# 移动了 479 次 A -> C
# 移动了 480 次 A -> C
# 移动了 481 次 A -> C
# 移动了 482 次 A -> C
# 移动了 483 次 A -> C
# 移动了 484 次 A -> C
# 移动了 485 次 A -> C
# 移动了 486 次 A -> C
# 移动了 487 次 A -> C
# 移动了 488 次 A -> C
# 移动了 489 次 A -> C
# 移动了 490 次 A -> C
# 移动了 491 次 A -> C
# 移动了 492 次 A -> C
# 移动了 493 次 A -> C
# 移动了 494 次 A -> C
# 移动了 495 次 A -> C
# 移动了 496 次 A -> C
# 移动了 497 次 A -> C
# 移动了 498 次 A -> C
# 移动了 499 次 A -> C
# 移动了 500 次 A -> C
# 移动了 501 次 A -> C
# 移动了 502 次 A -> C
# 移动了 503 次 A -> C
# 移动了 504 次 A -> C
# 移动了 505 次 A -> C
# 移动了 506 次 A -> C
# 移动了 507 次 A -> C
# 移动了 508 次 A -> C
# 移动了 509 次 A -> C
# 移动了 510 次 A -> C
# 移动了 511 次 A -> C
# 移动了 512 次 A -> C
# 移动了 513 次 A -> C
# 移动了 514 次 A -> C
# 移动了 515 次 A -> C
# 移动了 516 次 A -> C
# 移动了 517 次 A -> C
# 移动了 518 次 A -> C
# 移动了 519 次 A -> C
# 移动了 520 次 A -> C
# 移动了 521 次 A -> C
# 移动了 522 次 A -> C
# 移动了 523 次 A -> C
# 移动了 524 次 A -> C
# 移动了 525 次 A -> C
# 移动了 526 次 A -> C
# 移动了 527 次 A -> C
# 移动了 528 次 A -> C
# 移动了 529 次 A -> C
# 移动了 530 次 A -> C
# 移动了 531 次 A -> C
# 移动了 532 次 A -> C
# 移动了 533 次 A -> C
# 移动了 534 次 A -> C
# 移动了 535 次 A -> C
# 移动了 536 次 A -> C
# 移动了 537 次 A -> C
# 移动了 538 次 A -> C
# 移动了 539 次 A -> C
# 移动了 540 次 A -> C
# 移动了 541 次 A -> C
# 移动了 542 次 A -> C
# 移动了 543 次 A -> C
# 移动了 544 次 A -> C
# 移动了 545 次 A -> C
# 移动了 546 次 A -> C
# 移动了 547 次 A -> C
# 移动了 548 次 A -> C
# 移动了 549 次 A -> C
# 移动了 550 次 A -> C
# 移动了 551 次 A -> C
# 移动了 552 次 A -> C
# 移动了 553 次 A -> C
# 移动了 554 次 A -> C
# 移动了 555 次 A -> C
# 移动了 556 次 A -> C
# 移动了 557 次 A -> C
# 移动了 558 次 A -> C
# 移动了 559 次 A -> C
# 移动了 560 次 A -> C
# 移动了 561 次 A -> C
# 移动了 562 次 A -> C
# 移动了 563 次 A -> C
# 移动了 564 次 A -> C
# 移动了 565 次 A -> C
# 移动了 566 次 A -> C
# 移动了 567 次 A -> C
# 移动了 568 次 A -> C
# 移动了 569 次 A -> C
# 移动了 570 次 A -> C
# 移动了 571 次 A -> C
# 移动了 572 次 A -> C
# 移动了 573 次 A -> C
# 移动了 574 次 A -> C
# 移动了 575 次 A -> C
# 移动了 576 次 A -> C
# 移动了 577 次 A -> C
# 移动了 578 次 A -> C
# 移动了 579 次 A -> C
# 移动了 580 次 A -> C
# 移动了 581 次 A -> C
# 移动了 582 次 A -> C
# 移动了 583 次 A -> C
# 移动了 584 次 A -> C
# 移动了 585 次 A -> C
# 移动了 586 次 A -> C
# 移动了 587 次 A -> C
# 移动了 588 次 A -> C
# 移动了 589 次 A -> C
# 移动了 590 次 A -> C
# 移动了 591 次 A -> C
# 移动了 592 次 A -> C
# 移动了 593 次 A -> C
# 移动了 594 次 A -> C
# 移动了 595 次 A -> C
# 移动了 596 次 A -> C
# 移动了 597 次 A -> C
# 移动了 598 次 A -> C
# 移动了 599 次 A -> C
# 移动了 600 次 A -> C
# 移动了 601 次 A -> C
# 移动了 602 次 A -> C
# 移动了 603 次 A -> C
# 移动了 604 次 A -> C
# 移动了 605 次 A -> C
# 移动了 606 次 A -> C
# 移动了 607 次 A -> C
# 移动了 608 次 A -> C
# 移动了 609 次 A -> C
# 移动了 610 次 A -> C
# 移动了 611 次 A -> C
# 移动了 612 次 A -> C
# 移动了 613 次 A -> C
# 移动了 614 次 A -> C
# 移动了 615 次 A -> C
# 移动了 616 次 A -> C
# 移动了 617 次 A -> C
# 移动了 618 次 A -> C
# 移动了 619 次 A -> C
# 移动了 620 次 A -> C
# 移动了 621 次 A -> C
# 移动了 622 次 A -> C
# 移动了 623 次 A -> C
# 移动了 624 次 A -> C
# 移动了 625 次 A -> C
# 移动了 626 次 A -> C
# 移动了 627 次 A -> C
# 移动了 628 次 A -> C
# 移动了 629 次 A -> C
# 移动了 630 次 A -> C
# 移动了 631 次 A -> C
# 移动了 632 次 A -> C
# 移动了 633 次 A -> C
# 移动了 634 次 A -> C
# 移动了 635 次 A -> C
# 移动了 636 次 A -> C
# 移动了 637 次 A -> C
# 移动了 638 次 A -> C
# 移动了 639 次 A -> C
# 移动了 640 次 A -> C
# 移动了 641 次 A -> C
# 移动了 642 次 A -> C
# 移动了 643 次 A -> C
# 移动了 644 次 A -> C
# 移动了 645 次 A -> C
# 移动了 646 次 A -> C
# 移动了 647 次 A -> C
# 移动了 648 次 A -> C
# 移动了 649 次 A -> C
# 移动了 650 次 A -> C
# 移动了 651 次 A -> C
# 移动了 652 次 A -> C
# 移动了 653 次 A -> C
# 移动了 654 次 A -> C
# 移动了 655 次 A -> C
# 移动了 656 次 A -> C
# 移动了 657 次 A -> C
# 移动了 658 次 A -> C
# 移动了 659 次 A -> C
# 移动了 660 次 A -> C
# 移动了 661 次 A -> C
# 移动了 662 次 A -> C
# 移动了 663 次 A -> C
# 移动了 664 次 A -> C
# 移动了 665 次 A -> C
# 移动了 666 次 A -> C
# 移动了 667 次 A -> C
# 移动了 668 次 A -> C
# 移动了 669 次 A -> C
# 移动了 670 次 A -> C
# 移动了 671 次 A -> C
# 移动了 672 次 A -> C
# 移动了 673 次 A -> C
# 移动了 674 次 A -> C
# 移动了 675 次 A -> C
# 移动了 676 次 A -> C
# 移动了 677 次 A -> C
# 移动了 678 次 A -> C
# 移动了 679 次 A -> C
# 移动了 680 次 A -> C
# 移动了 681 次 A -> C
# 移动了 682 次 A -> C
# 移动了 683 次 A -> C
# 移动了 684 次 A -> C
# 移动了 685 次 A -> C
# 移动了 686 次 A -> C
# 移动了 687 次 A -> C
# 移动了 688 次 A -> C
# 移动了 689 次 A -> C
# 移动了 690 次 A -> C
# 移动了 691 次 A -> C
# 移动了 692 次 A -> C
# 移动了 693 次 A -> C
# 移动了 694 次 A -> C
# 移动了 695 次 A -> C
# 移动了 696 次 A -> C
# 移动了 697 次 A -> C
# 移动了 698 次 A -> C
# 移动了 699 次 A -> C
# 移动了 700 次 A -> C
# 移动了 701 次 A -> C
# 移动了 702 次 A -> C
# 移动了 703 次 A -> C
# 移动了 704 次 A -> C
# 移动了 705 次 A -> C
# 移动了 706 次 A -> C
# 移动了 707 次 A -> C
# 移动了 708 次 A -> C
# 移动了 709 次 A -> C
# 移动了 710 次 A -> C
# 移动了 711 次 A -> C
# 移动了 712 次 A -> C
# 移动了 713 次 A -> C
# 移动了 714 次 A -> C
# 移动了 715 次 A -> C
# 移动了 716 次 A -> C
# 移动了 717 次 A -> C
# 移动了 718 次 A -> C
# 移动了 719 次 A -> C
# 移动了 720 次 A -> C
# 移动了 721 次 A -> C
# 移动了 722 次 A -> C
# 移动了 723 次 A -> C
# 移动了 724 次 A -> C
# 移动了 725 次 A -> C
# 移动了 726 次 A -> C
# 移动了 727 次 A -> C
# 移动了 728 次 A -> C
# 移动了 729 次 A -> C
# 移动了 730 次 A -> C
# 移动了 731 次 A -> C
# 移动了 732 次 A -> C
# 移动了 733 次 A -> C
# 移动了 734 次 A -> C
# 移动了 735 次 A -> C
# 移动了 736 次 A -> C
# 移动了 737 次 A -> C
# 移动了 738 次 A -> C
# 移动了 739 次 A -> C
# 移动了 740 次 A -> C
# 移动了 741 次 A -> C
# 移动了 742 次 A -> C
# 移动了 743 次 A -> C
# 移动了 744 次 A -> C
# 移动了 745 次 A -> C
# 移动了 746 次 A -> C
# 移动了 747 次 A -> C
# 移动了 748 次 A -> C
# 移动了 749 次 A -> C
# 移动了 750 次 A -> C
# 移动了 751 次 A -> C
# 移动了 752 次 A -> C
# 移动了 753 次 A -> C
# 移动了 754 次 A -> C
# 移动了 755 次 A -> C
# 移动了 756 次 A -> C
# 移动了 757 次 A -> C
# 移动了 758 次 A -> C
# 移动了 759 次 A -> C
# 移动了 760 次 A -> C
# 移动了 761 次 A -> C
# 移动了 762 次 A -> C
# 移动了 763 次 A -> C
# 移动了 764 次 A -> C
# 移动了 765 次 A -> C
# 移动了 766 次 A -> C
# 移动了 767 次 A -> C
# 移动了 768 次 A -> C
# 移动了 769 次 A -> C
# 移动了 770 次 A -> C
# 移动了 771 次 A -> C
# 移动了 772 次 A -> C
# 移动了 773 次 A -> C
# 移动了 774 次 A -> C
# 移动了 775 次 A -> C
# 移动了 776 次 A -> C
# 移动了 777 次 A -> C
# 移动了 778 次 A -> C
# 移动了 779 次 A -> C
# 移动了 780 次 A -> C
# 移动了 781 次 A -> C
# 移动了 782 次 A -> C
# 移动了 783 次 A -> C
# 移动了 784 次 A -> C
# 移动了 785 次 A -> C
# 移动了 786 次 A -> C
# 移动了 787 次 A -> C
# 移动了 788 次 A -> C
# 移动了 789 次 A -> C
# 移动了 790 次 A -> C
# 移动了 791 次 A -> C
# 移动了 792 次 A -> C
# 移动了 793 次 A -> C
# 移动了 794 次 A -> C
# 移动了 795 次 A -> C
# 移动了 796 次 A -> C
# 移动了 797 次 A -> C
# 移动了 798 次 A -> C
# 移动了 799 次 A -> C
# 移动了 800 次 A -> C
# 移动了 801 次 A -> C
# 移动了 802 次 A -> C
# 移动了 803 次 A -> C
# 移动了 804 次 A -> C
# 移动了 805 次 A -> C
# 移动了 806 次 A -> C
# 移动了 807 次 A -> C
# 移动了 808 次 A -> C
# 移动了 809 次 A -> C
# 移动了 810 次 A -> C
# 移动了 811 次 A -> C
# 移动了 812 次 A -> C
# 移动了 813 次 A -> C
# 移动了 814 次 A -> C
# 移动了 815 次 A -> C
# 移动了 816 次 A -> C
# 移动了 817 次 A -> C
# 移动了 818 次 A -> C
# 移动了 819 次 A -> C
# 移动了 820 次 A -> C
# 移动了 821 次 A -> C
# 移动了 822 次 A -> C
# 移动了 823 次 A -> C
# 移动了 824 次 A -> C
# 移动了 825 次 A -> C
# 移动了 826 次 A -> C
# 移动了 827 次 A -> C
# 移动了 828 次 A -> C
# 移动了 829 次 A -> C
# 移动了 830 次 A -> C
# 移动了 831 次 A -> C
# 移动了 832 次 A -> C
# 移动了 833 次 A -> C
# 移动了 834 次 A -> C
# 移动了 835 次 A -> C
# 移动了 836 次 A -> C
# 移动了 837 次 A -> C
# 移动了 838 次 A -> C
# 移动了 839 次 A -> C
# 移动了 840 次 A -> C
# 移动了 841 次 A -> C
# 移动了 842 次 A -> C
# 移动了 843 次 A -> C
# 移动了 844 次 A -> C
# 移动了 845 次 A -> C
# 移动了 846 次 A -> C
# 移动了 847 次 A -> C
# 移动了 848 次 A -> C
# 移动了 849 次 A -> C
# 移动了 850 次 A -> C
# 移动了 851 次 A -> C
# 移动了 852 次 A -> C
# 移动了 853 次 A -> C
# 移动了 854 次 A -> C
# 移动了 855 次 A -> C
# 移动了 856 次 A -> C
# 移动了 857 次 A -> C
# 移动了 858 次 A -> C
# 移动了 859 次 A -> C
# 移动了 860 次 A -> C
# 移动了 861 次 A -> C
# 移动了 862 次 A -> C
# 移动了 863 次 A -> C
# 移动了 864 次 A -> C
# 移动了 865 次 A -> C
# 移动了 866 次 A -> C
# 移动了 867 次 A -> C
# 移动了 868 次 A -> C
# 移动了 869 次 A -> C
# 移动了 870 次 A -> C
# 移动了 871 次 A -> C
# 移动了 872 次 A -> C
# 移动了 873 次 A -> C
# 移动了 874 次 A -> C
# 移动了 875 次 A -> C
# 移动了 876 次 A -> C
# 移动了 877 次 A -> C
# 移动了 878 次 A -> C
# 移动了 879 次 A -> C
# 移动了 880 次 A -> C
# 移动了 881 次 A -> C
# 移动了 882 次 A -> C
# 移动了 883 次 A -> C
# 移动了 884 次 A -> C
# 移动了 885 次 A -> C
# 移动了 886 次 A -> C
# 移动了 887 次 A -> C
# 移动了 888 次 A -> C
# 移动了 889 次 A -> C
# 移动了 890 次 A -> C
# 移动了 891 次 A -> C
# 移动了 892 次 A -> C
# 移动了 893 次 A -> C
# 移动了 894 次 A -> C
# 移动了 895 次 A -> C
# 移动了 896 次 A -> C
# 移动了 897 次 A -> C
# 移动了 898 次 A -> C
# 移动了 899 次 A -> C
# 移动了 900 次 A -> C
# 移动了 901 次 A -> C
# 移动了 902 次 A -> C
# 移动了 903 次 A -> C
# 移动了 904 次 A -> C
# 移动了 905 次 A -> C
# 移动了 906 次 A -> C
# 移动了 907 次 A -> C
# 移动了 908 次 A -> C
# 移动了 909 次 A -> C
# 移动了 910 次 A -> C
# 移动了 911 次 A -> C
# 移动了 912 次 A -> C
# 移动了 913 次 A -> C
# 移动了 914 次 A -> C
# 移动了 915 次 A -> C
# 移动了 916 次 A -> C
# 移动了 917 次 A -> C
# 移动了 918 次 A -> C
# 移动了 919 次 A -> C
# 移动了 920 次 A -> C
# 移动了 921 次 A -> C
# 移动了 922 次 A -> C
# 移动了 923 次 A -> C
# 移动了 924 次 A -> C
# 移动了 925 次 A -> C
# 移动了 926 次 A -> C
# 移动了 927 次 A -> C
# 移动了 928 次 A -> C
# 移动了 929 次 A -> C
# 移动了 930 次 A -> C
# 移动了 931 次 A -> C
# 移动了 932 次 A -> C
# 移动了 933 次 A -> C
# 移动了 934 次 A -> C
# 移动了 935 次 A -> C
# 移动了 936 次 A -> C
# 移动了 937 次 A -> C
# 移动了 938 次 A -> C
# 移动了 939 次 A -> C
# 移动了 940 次 A -> C
# 移动了 941 次 A -> C
# 移动了 942 次 A -> C
# 移动了 943 次 A -> C
# 移动了 944 次 A -> C
# 移动了 945 次 A -> C
# 移动了 946 次 A -> C
# 移动了 947 次 A -> C
# 移动了 948 次 A -> C
# 移动了 949 次 A -> C
# 移动了 950 次 A -> C
# 移动了 951 次 A -> C
# 移动了 952 次 A -> C
# 移动了 953 次 A -> C
# 移动了 954 次 A -> C
# 移动了 955 次 A -> C
# 移动了 956 次 A -> C
# 移动了 957 次 A -> C
# 移动了 958 次 A -> C
# 移动了 959 次 A -> C
# 移动了 960 次 A -> C
# 移动了 961 次 A -> C
# 移动了 962 次 A -> C
# 移动了 963 次 A -> C
# 移动了 964 次 A -> C
# 移动了 965 次 A -> C
# 移动了 966 次 A -> C
# 移动了 967 次 A -> C
# 移动了 968 次 A -> C
# 移动了 969 次 A -> C
# 移动了 970 次 A -> C
# 移动了 971 次 A -> C
# 移动了 972 次 A -> C
# 移动了 973 次 A -> C
# 移动了 974 次 A -> C
# 移动了 975 次 A -> C
# 移动了 976 次 A -> C
# 移动了 977 次 A -> C
# 移动了 978 次 A -> C
# 移动了 979 次 A -> C
# 移动了 980 次 A -> C
# 移动了 981 次 A -> C
# 移动了 982 次 A -> C
# 移动了 983 次 A -> C
# 移动了 984 次 A -> C
# 移动了 985 次 A -> C
# 移动了 986 次 A -> C
# 移动了 987 次 A -> C
# 移动了 988 次 A -> C
# 移动了 989 次 A -> C
# 移动了 990 次 A -> C
# 移动了 991 次 A -> C
# 移动了 992 次 A -> C
# 移动了 993 次 A -> C
# 移动了 994 次 A -> C
# 移动了 995 次 A -> C
# 移动了 996 次 A -> C
# 移动了 997 次 A -> C
# 移动了 998 次 A -> C
# 移动了 999 次 A -> C
# 移动了 1000 次 A -> C
# 移动了 1001 次 A -> C
# 移动了 1002 次 A -> C
# 移动了 1003 次 A -> C
# 移动了 1004 次 A -> C
# 移动了 1005 次 A -> C
# 移动了 1006 次 A -> C
# 移动了 1007 次 A -> C
# 移动了 1008 次 A -> C
# 移动了 1009 次 A -> C
# 移动了 1010 次 A -> C
# 移动了 1011 次 A -> C
# 移动了 1012 次 A -> C
# 移动了 1013 次 A -> C
# 移动了 1014 次 A -> C
# 移动了 1015 次 A -> C
# 移动了 1016 次 A -> C
# 移动了 1017 次 A -> C
# 移动了 1018 次 A -> C
# 移动了 1019 次 A -> C
# 移动了 1020 次 A -> C
# 移动了 1021 次 A -> C
# 移动了 1022 次 A -> C
# 移动了 1023 次 A -> C
# 移动了 1024 次 A -> C
# 移动了 1025 次 A -> C
# 移动了 1026 次 A -> C
# 移动了 1027 次 A -> C
# 移动了 1028 次 A -> C
# 移动了 1029 次 A -> C
# 移动了 1030 次 A -> C
# 移动了 1031 次 A -> C
# 移动了 1032 次 A -> C
# 移动了 1033 次 A -> C
# 移动了 1034 次 A -> C
# 移动了 1035 次 A -> C
# 移动了 1036 次 A -> C
# 移动了 1037 次 A -> C
# 移动了 1038 次 A -> C
# 移动了 1039 次 A -> C
# 移动了 1040 次 A -> C
# 移动了 1041 次 A -> C
# 移动了 1042 次 A -> C
# 移动了 1043 次 A -> C
# 移动了 1044 次 A -> C
# 移动了 1045 次 A -> C
# 移动了 1046 次 A -> C
# 移动了 1047 次 A -> C
# 移动了 1048 次 A -> C
# 移动了 1049 次 A -> C
# 移动了 1050 次 A -> C
# 移动了 1051 次 A -> C
# 移动了 1052 次 A -> C
# 移动了 1053 次 A -> C
# 移动了 1054 次 A -> C
# 移动了 1055 次 A -> C
# 移动了 1056 次 A -> C
# 移动了 1057 次 A -> C
# 移动了 1058 次 A -> C
# 移动了 1059 次 A -> C
# 移动了 1060 次 A -> C
# 移动了 1061 次 A -> C
# 移动了 1062 次 A -> C
# 移动了 1063 次 A -> C
# 移动了 1064 次 A -> C
# 移动了 1065 次 A -> C
# 移动了 1066 次 A -> C
# 移动了 1067 次 A -> C
# 移动了 1068 次 A -> C
# 移动了 1069 次 A -> C
# 移动了 1070 次 A -> C
# 移动了 1071 次 A -> C
# 移动了 1072 次 A -> C
# 移动了 1073 次 A -> C
# 移动了 1074 次 A -> C
# 移动了 1075 次 A -> C
# 移动了 1076 次 A -> C
# 移动了 1077 次 A -> C
# 移动了 1078 次 A -> C
# 移动了 1079 次 A -> C
# 移动了 1080 次 A -> C
# 移动了 1081 次 A -> C
# 移动了 1082 次 A -> C
# 移动了 1083 次 A -> C
# 移动了 1084 次 A -> C
# 移动了 1085 次 A -> C
# 移动了 1086 次 A -> C
# 移动了 1087 次 A -> C
# 移动了 1088 次 A -> C
# 移动了 1089 次 A -> C
# 移动了 1090 次 A -> C
# 移动了 1091 次 A -> C
# 移动了 1092 次 A -> C
# 移动了 1093 次 A -> C
# 移动了 1094 次 A -> C
# 移动了 1095 次 A -> C
# 移动了 1096 次 A -> C
# 移动了 1097 次 A -> C
# 移动了 1098 次 A -> C
# 移动了 1099 次 A -> C
# 移动了 1100 次 A -> C
# 移动了 1101 次 A -> C
# 移动了 1102 次 A -> C
# 移动了 1103 次 A -> C
# 移动了 1104 次 A -> C
# 移动了 1105 次 A -> C
# 移动了 1106 次 A -> C
# 移动了 1107 次 A -> C
# 移动了 1108 次 A -> C
# 移动了 1109 次 A -> C
# 移动了 1110 次 A -> C
# 移动了 1111 次 A -> C
# 移动了 1112 次 A -> C
# 移动了 1113 次 A -> C
# 移动了 1114 次 A -> C
# 移动了 1115 次 A -> C
# 移动了 1116 次 A -> C
# 移动了 1117 次 A -> C
# 移动了 1118 次 A -> C
# 移动了 1119 次 A -> C
# 移动了 1120 次 A -> C
# 移动了 1121 次 A -> C
# 移动了 1122 次 A -> C
# 移动了 1123 次 A -> C
# 移动了 1124 次 A -> C
# 移动了 1125 次 A -> C
# 移动了 1126 次 A -> C
# 移动了 1127 次 A -> C
# 移动了 1128 次 A -> C
# 移动了 1129 次 A -> C
# 移动了 1130 次 A -> C
# 移动了 1131 次 A -> C
# 移动了 1132 次 A -> C
# 移动了 1133 次 A -> C
# 移动了 1134 次 A -> C
# 移动了 1135 次 A -> C
# 移动了 1136 次 A -> C
# 移动了 1137 次 A -> C
# 移动了 1138 次 A -> C
# 移动了 1139 次 A -> C
# 移动了 1140 次 A -> C
# 移动了 1141 次 A -> C
# 移动了 1142 次 A -> C
# 移动了 1143 次 A -> C
# 移动了 1144 次 A -> C
# 移动了 1145 次 A -> C
# 移动了 1146 次 A -> C
# 移动了 1147 次 A -> C
# 移动了 1148 次 A -> C
# 移动了 1149 次 A -> C
# 移动了 1150 次 A -> C
# 移动了 1151 次 A -> C
# 移动了 1152 次 A -> C
# 移动了 1153 次 A -> C
# 移动了 1154 次 A -> C
# 移动了 1155 次 A -> C
# 移动了 1156 次 A -> C
# 移动了 1157 次 A -> C
# 移动了 1158 次 A -> C
# 移动了 1159 次 A -> C
# 移动了 1160 次 A -> C
# 移动了 1161 次 A -> C
# 移动了 1162 次 A -> C
# 移动了 1163 次 A -> C
# 移动了 1164 次 A -> C
# 移动了 1165 次 A -> C
# 移动了 1166 次 A -> C
# 移动了 1167 次 A -> C
# 移动了 1168 次 A -> C
# 移动了 1169 次 A -> C
# 移动了 1170 次 A -> C
# 移动了 1171 次 A -> C
# 移动了 1172 次 A -> C
# 移动了 1173 次 A -> C
# 移动了 1174 次 A -> C
# 移动了 1175 次 A -> C
# 移动了 1176 次 A -> C
# 移动了 1177 次 A -> C
# 移动了 1178 次 A -> C
# 移动了 1179 次 A -> C
# 移动了 1180 次 A -> C
# 移动了 1181 次 A -> C
# 移动了 1182 次 A -> C
# 移动了 1183 次 A -> C
# 移动了 1184 次 A -> C
# 移动了 1185 次 A -> C
# 移动了 1186 次 A -> C
# 移动了 1187 次 A -> C
# 移动了 1188 次 A -> C
# 移动了 1189 次 A -> C
# 移动了 1190 次 A -> C
# 移动了 1191 次 A -> C
# 移动了 1192 次 A -> C
# 移动了 1193 次 A -> C
# 移动了 1194 次 A -> C
# 移动了 1195 次 A -> C
# 移动了 1196 次 A -> C
# 移动了 1197 次 A -> C
# 移动了 1198 次 A -> C
# 移动了 1199 次 A -> C
# 移动了 1200 次 A -> C
# 移动了 1201 次 A -> C
# 移动了 1202 次 A -> C
# 移动了 1203 次 A -> C
# 移动了 1204 次 A -> C
# 移动了 1205 次 A -> C
# 移动了 1206 次 A -> C
# 移动了 1207 次 A -> C
# 移动了 1208 次 A -> C
# 移动了 1209 次 A -> C
# 移动了 1210 次 A -> C
# 移动了 1211 次 A -> C
# 移动了 1212 次 A -> C
# 移动了 1213 次 A -> C
# 移动了 1214 次 A -> C
# 移动了 1215 次 A -> C
# 移动了 1216 次 A -> C
# 移动了 1217 次 A -> C
# 移动了 1218 次 A -> C
# 移动了 1219 次 A -> C
# 移动了 1220 次 A -> C
# 移动了 1221 次 A -> C
# 移动了 1222 次 A -> C
# 移动了 1223 次 A -> C
# 移动了 1224 次 A -> C
# 移动了 1225 次 A -> C
# 移动了 1226 次 A -> C
# 移动了 1227 次 A -> C
# 移动了 1228 次 A -> C
# 移动了 1229 次 A -> C
# 移动了 1230 次 A -> C
# 移动了 1231 次 A -> C
# 移动了 1232 次 A -> C
# 移动了 1233 次 A -> C
# 移动了 1234 次 A -> C
# 移动了 1235 次 A -> C
# 移动了 1236 次 A -> C
# 移动了 1237 次 A -> C
# 移动了 1238 次 A -> C
# 移动了 1239 次 A -> C
# 移动了 1240 次 A -> C
# 移动了 1241 次 A -> C
# 移动了 1242 次 A -> C
# 移动了 1243 次 A -> C
# 移动了 1244 次 A -> C
# 移动了 1245 次 A -> C
# 移动了 1246 次 A -> C
# 移动了 1247 次 A -> C
# 移动了 1248 次 A -> C
# 移动了 1249 次 A -> C
# 移动了 1250 次 A -> C
# 移动了 1251 次 A -> C
# 移动了 1252 次 A -> C
# 移动了 1253 次 A -> C
# 移动了 1254 次 A -> C
# 移动了 1255 次 A -> C
# 移动了 1256 次 A -> C
# 移动了 1257 次 A -> C
# 移动了 1258 次 A -> C
# 移动了 1259 次 A -> C
# 移动了 1260 次 A -> C
# 移动了 1261 次 A -> C
# 移动了 1262 次 A -> C
# 移动了 1263 次 A -> C
# 移动了 1264 次 A -> C
# 移动了 1265 次 A -> C
# 移动了 1266 次 A -> C
# 移动了 1267 次 A -> C
# 移动了 1268 次 A -> C
# 移动了 1269 次 A -> C
# 移动了 1270 次 A -> C
# 移动了 1271 次 A -> C
# 移动了 1272 次 A -> C
# 移动了 1273 次 A -> C
# 移动了 1274 次 A -> C
# 移动了 1275 次 A -> C
# 移动了 1276 次 A -> C
# 移动了 1277 次 A -> C
# 移动了 1278 次 A -> C
# 移动了 1279 次 A -> C
# 移动了 1280 次 A -> C
# 移动了 1281 次 A -> C
# 移动了 1282 次 A -> C
# 移动了 1283 次 A -> C
# 移动了 1284 次 A -> C
# 移动了 1285 次 A -> C
# 移动了 1286 次 A -> C
# 移动了 1287 次 A -> C
# 移动了 1288 次 A -> C
# 移动了 1289 次 A -> C
# 移动了 1290 次 A -> C
# 移动了 1291 次 A -> C
# 移动了 1292 次 A -> C
# 移动了 1293 次 A -> C
# 移动了 1294 次 A -> C
# 移动了 1295 次 A -> C
# 移动了 1296 次 A -> C
# 移动了 1297 次 A -> C
# 移动了 1298 次 A -> C
# 移动了 1299 次 A -> C
# 移动了 1300 次 A -> C
# 移动了 1301 次 A -> C
# 移动了 1302 次 A -> C
# 移动了 1303 次 A -> C
# 移动了 1304 次 A -> C
# 移动了 1305 次 A -> C
# 移动了 1306 次 A -> C
# 移动了 1307 次 A -> C
# 移动了 1308 次 A -> C
# 移动了 1309 次 A -> C
# 移动了 1310 次 A -> C
# 移动了 1311 次 A -> C
# 移动了 1312 次 A -> C
# 移动了 1313 次 A -> C
# 移动了 1314 次 A -> C
# 移动了 1315 次 A -> C
# 移动了 1316 次 A -> C
# 移动了 1317 次 A -> C
# 移动了 1318 次 A -> C
# 移动了 1319 次 A -> C
# 移动了 1320 次 A -> C
# 移动了 1321 次 A -> C
# 移动了 1322 次 A -> C
# 移动了 1323 次 A -> C
# 移动了 1324 次 A -> C
# 移动了 1325 次 A -> C
# 移动了 1326 次 A -> C
# 移动了 1327 次 A -> C
# 移动了 1328 次 A -> C
# 移动了 1329 次 A -> C
# 移动了 1330 次 A -> C
# 移动了 1331 次 A -> C
# 移动了 1332 次 A -> C
# 移动了 1333 次 A -> C
# 移动了 1334 次 A -> C
# 移动了 1335 次 A -> C
# 移动了 1336 次 A -> C
# 移动了 1337 次 A -> C
# 移动了 1338 次 A -> C
# 移动了 1339 次 A -> C
# 移动了 1340 次 A -> C
# 移动了 1341 次 A -> C
# 移动了 1342 次 A -> C
# 移动了 1343 次 A -> C
# 移动了 1344 次 A -> C
# 移动了 1345 次 A -> C
# 移动了 1346 次 A -> C
# 移动了 1347 次 A -> C
# 移动了 1348 次 A -> C
# 移动了 1349 次 A -> C
# 移动了 1350 次 A -> C
# 移动了 1351 次 A -> C
# 移动了 1352 次 A -> C
# 移动了 1353 次 A -> C
# 移动了 1354 次 A -> C
# 移动了 1355 次 A -> C
# 移动了 1356 次 A -> C
# 移动了 1357 次 A -> C
# 移动了 1358 次 A -> C
# 移动了 1359 次 A -> C
# 移动了 1360 次 A -> C
# 移动了 1361 次 A -> C
# 移动了 1362 次 A -> C
# 移动了 1363 次 A -> C
# 移动了 1364 次 A -> C
# 移动了 1365 次 A -> C
# 移动了 1366 次 A -> C
# 移动了 1367 次 A -> C
# 移动了 1368 次 A -> C
# 移动了 1369 次 A -> C
# 移动了 1370 次 A -> C
# 移动了 1371 次 A -> C
# 移动了 1372 次 A -> C
# 移动了 1373 次 A -> C
# 移动了 1374 次 A -> C
# 移动了 1375 次 A -> C
# 移动了 1376 次 A -> C
# 移动了 1377 次 A -> C
# 移动了 1378 次 A -> C
# 移动了 1379 次 A -> C
# 移动了 1380 次 A -> C
# 移动了 1381 次 A -> C
# 移动了 1382 次 A -> C
# 移动了 1383 次 A -> C
# 移动了 1384 次 A -> C
# 移动了 1385 次 A -> C
# 移动了 1386 次 A -> C
# 移动了 1387 次 A -> C
# 移动了 1388 次 A -> C
# 移动了 1389 次 A -> C
# 移动了 1390 次 A -> C
# 移动了 1391 次 A -> C
# 移动了 1392 次 A -> C
# 移动了 1393 次 A -> C
# 移动了 1394 次 A -> C
# 移动了 1395 次 A -> C
# 移动了 1396 次 A -> C
# 移动了 1397 次 A -> C
# 移动了 1398 次 A -> C
# 移动了 1399 次 A -> C
# 移动了 1400 次 A -> C
# 移动了 1401 次 A -> C
# 移动了 1402 次 A -> C
# 移动了 1403 次 A -> C
# 移动了 1404 次 A -> C
# 移动了 1405 次 A -> C
# 移动了 1406 次 A -> C
# 移动了 1407 次 A -> C
# 移动了 1408 次 A -> C
# 移动了 1409 次 A -> C
# 移动了 1410 次 A -> C
# 移动了 1411 次 A -> C
# 移动了 1412 次 A -> C
# 移动了 1413 次 A -> C
# 移动了 1414 次 A -> C
# 移动了 1415 次 A -> C
# 移动了 1416 次 A -> C
# 移动了 1417 次 A -> C
# 移动了 1418 次 A -> C
# 移动了 1419 次 A -> C
# 移动了 1420 次 A -> C
# 移动了 1421 次 A -> C
# 移动了 1422 次 A -> C
# 移动了 1423 次 A -> C
# 移动了 1424 次 A -> C
# 移动了 1425 次 A -> C
# 移动了 1426 次 A -> C
# 移动了 1427 次 A -> C
# 移动了 1428 次 A -> C
# 移动了 1429 次 A -> C
# 移动了 1430 次 A -> C
# 移动了 1431 次 A -> C
# 移动了 1432 次 A -> C
# 移动了 1433 次 A -> C
# 移动了 1434 次 A -> C
# 移动了 1435 次 A -> C
# 移动了 1436 次 A -> C
# 移动了 1437 次 A -> C
# 移动了 1438 次 A -> C
# 移动了 1439 次 A -> C
# 移动了 1440 次 A -> C
# 移动了 1441 次 A -> C
# 移动了 1442 次 A -> C
# 移动了 1443 次 A -> C
# 移动了 1444 次 A -> C
# 移动了 1445 次 A -> C
# 移动了 1446 次 A -> C
# 移动了 1447 次 A -> C
# 移动了 1448 次 A -> C
# 移动了 1449 次 A -> C
# 移动了 1450 次 A -> C
# 移动了 1451 次 A -> C
# 移动了 1452 次 A -> C
# 移动了 1453 次 A -> C
# 移动了 1454 次 A -> C
# 移动了 1455 次 A -> C
# 移动了 1456 次 A -> C
# 移动了 1457 次 A -> C
# 移动了 1458 次 A -> C
# 移动了 1459 次 A -> C
# 移动了 1460 次 A -> C
# 移动了 1461 次 A -> C
# 移动了 1462 次 A -> C
# 移动了 1463 次 A -> C
# 移动了 1464 次 A -> C
# 移动了 1465 次 A -> C
# 移动了 1466 次 A -> C
# 移动了 1467 次 A -> C
# 移动了 1468 次 A -> C
# 移动了 1469 次 A -> C
# 移动了 1470 次 A -> C
# 移动了 1471 次 A -> C
# 移动了 1472 次 A -> C
# 移动了 1473 次 A -> C
# 移动了 1474 次 A -> C
# 移动了 1475 次 A -> C
# 移动了 1476 次 A -> C
# 移动了 1477 次 A -> C
# 移动了 1478 次 A -> C
# 移动了 1479 次 A -> C
# 移动了 1480 次 A -> C
# 移动了 1481 次 A -> C
# 移动了 1482 次 A -> C
# 移动了 1483 次 A -> C
# 移动了 1484 次 A -> C
# 移动了 1485 次 A -> C
# 移动了 1486 次 A -> C
# 移动了 1487 次 A -> C
# 移动了 1488 次 A -> C
# 移动了 1489 次 A -> C
# 移动了 1490 次 A -> C
# 移动了 1491 次 A -> C
# 移动了 1492 次 A -> C
# 移动了 1493 次 A -> C
# 移动了 1494 次 A -> C
# 移动了 1495 次 A -> C
# 移动了 1496 次 A -> C
# 移动了 1497 次 A -> C
# 移动了 1498 次 A -> C
# 移动了 1499 次 A -> C
# 移动了 1500 次 A -> C
# 移动了 1501 次 A -> C
# 移动了 1502 次 A -> C
# 移动了 1503 次 A -> C
# 移动了 1504 次 A -> C
# 移动了 1505 次 A -> C
# 移动了 1506 次 A -> C
# 移动了 1507 次 A -> C
# 移动了 1508 次 A -> C
# 移动了 1509 次 A -> C
# 移动了 1510 次 A -> C
# 移动了 1511 次 A -> C
# 移动了 1512 次 A -> C
# 移动了 1513 次 A -> C
# 移动了 1514 次 A -> C
# 移动了 1515 次 A -> C
# 移动了 1516 次 A -> C
# 移动了 1517 次 A -> C
# 移动了 1518 次 A -> C
# 移动了 1519 次 A -> C
# 移动了 1520 次 A -> C
# 移动了 1521 次 A -> C
# 移动了 1522 次 A -> C
# 移动了 1523 次 A -> C
# 移动了 1524 次 A -> C
# 移动了 1525 次 A -> C
# 移动了 1526 次 A -> C
# 移动了 1527 次 A -> C
# 移动了 1528 次 A -> C
# 移动了 1529 次 A -> C
# 移动了 1530 次 A -> C
# 移动了 1531 次 A -> C
# 移动了 1532 次 A -> C
# 移动了 1533 次 A -> C
# 移动了 1534 次 A -> C
# 移动了 1535 次 A -> C
# 移动了 1536 次 A -> C
# 移动了 1537 次 A -> C
# 移动了 1538 次 A -> C
# 移动了 1539 次 A -> C
# 移动了 1540 次 A -> C
# 移动了 1541 次 A -> C
# 移动了 1542 次 A -> C
# 移动了 1543 次 A -> C
# 移动了 1544 次 A -> C
# 移动了 1545 次 A -> C
# 移动了 1546 次 A -> C
# 移动了 1547 次 A -> C
# 移动了 1548 次 A -> C
# 移动了 1549 次 A -> C
# 移动了 1550 次 A -> C
# 移动了 1551 次 A -> C
# 移动了 1552 次 A -> C
# 移动了 1553 次 A -> C
# 移动了 1554 次 A -> C
# 移动了 1555 次 A -> C
# 移动了 1556 次 A -> C
# 移动了 1557 次 A -> C
# 移动了 1558 次 A -> C
# 移动了 1559 次 A -> C
# 移动了 1560 次 A -> C
# 移动了 1561 次 A -> C
# 移动了 1562 次 A -> C
# 移动了 1563 次 A -> C
# 移动了 1564 次 A -> C
# 移动了 1565 次 A -> C
# 移动了 1566 次 A -> C
# 移动了 1567 次 A -> C
# 移动了 1568 次 A -> C
# 移动了 1569 次 A -> C
# 移动了 1570 次 A -> C
# 移动了 1571 次 A -> C
# 移动了 1572 次 A -> C
# 移动了 1573 次 A -> C
# 移动了 1574 次 A -> C
# 移动了 1575 次 A -> C
# 移动了 1576 次 A -> C
# 移动了 1577 次 A -> C
# 移动了 1578 次 A -> C
# 移动了 1579 次 A -> C
# 移动了 1580 次 A -> C
# 移动了 1581 次 A -> C
# 移动了 1582 次 A -> C
# 移动了 1583 次 A -> C
# 移动了 1584 次 A -> C
# 移动了 1585 次 A -> C
# 移动了 1586 次 A -> C
# 移动了 1587 次 A -> C
# 移动了 1588 次 A -> C
# 移动了 1589 次 A -> C
# 移动了 1590 次 A -> C
# 移动了 1591 次 A -> C
# 移动了 1592 次 A -> C
# 移动了 1593 次 A -> C
# 移动了 1594 次 A -> C
# 移动了 1595 次 A -> C
# 移动了 1596 次 A -> C
# 移动了 1597 次 A -> C
# 移动了 1598 次 A -> C
# 移动了 1599 次 A -> C
# 移动了 1600 次 A -> C
# 移动了 1601 次 A -> C
# 移动了 1602 次 A -> C
# 移动了 1603 次 A -> C
# 移动了 1604 次 A -> C
# 移动了 1605 次 A -> C
# 移动了 1606 次 A -> C
# 移动了 1607 次 A -> C
# 移动了 1608 次 A -> C
# 移动了 1609 次 A -> C
# 移动了 1610 次 A -> C
# 移动了 1611 次 A -> C
# 移动了 1612 次 A -> C
# 移动了 1613 次 A -> C
# 移动了 1614 次 A -> C
# 移动了 1615 次 A -> C
# 移动了 1616 次 A -> C
# 移动了 1617 次 A -> C
# 移动了 1618 次 A -> C
# 移动了 1619 次 A -> C
# 移动了 1620 次 A -> C
# 移动了 1621 次 A -> C
# 移动了 1622 次 A -> C
# 移动了 1623 次 A -> C
# 移动了 1624 次 A -> C
# 移动了 1625 次 A -> C
# 移动了 1626 次 A -> C
# 移动了 1627 次 A -> C
# 移动了 1628 次 A -> C
# 移动了 1629 次 A -> C
# 移动了 1630 次 A -> C
# 移动了 1631 次 A -> C
# 移动了 1632 次 A -> C
# 移动了 1633 次 A -> C
# 移动了 1634 次 A -> C
# 移动了 1635 次 A -> C
# 移动了 1636 次 A -> C
# 移动了 1637 次 A -> C
# 移动了 1638 次 A -> C
# 移动了 1639 次 A -> C
# 移动了 1640 次 A -> C
# 移动了 1641 次 A -> C
# 移动了 1642 次 A -> C
# 移动了 1643 次 A -> C
# 移动了 1644 次 A -> C
# 移动了 1645 次 A -> C
# 移动了 1646 次 A -> C
# 移动了 1647 次 A -> C
# 移动了 1648 次 A -> C
# 移动了 1649 次 A -> C
# 移动了 1650 次 A -> C
# 移动了 1651 次 A -> C
# 移动了 1652 次 A -> C
# 移动了 1653 次 A -> C
# 移动了 1654 次 A -> C
# 移动了 1655 次 A -> C
# 移动了 1656 次 A -> C
# 移动了 1657 次 A -> C
# 移动了 1658 次 A -> C
# 移动了 1659 次 A -> C
# 移动了 1660 次 A -> C
# 移动了 1661 次 A -> C
# 移动了 1662 次 A -> C
# 移动了 1663 次 A -> C
# 移动了 1664 次 A -> C
# 移动了 1665 次 A -> C
# 移动了 1666 次 A -> C
# 移动了 1667 次 A -> C
# 移动了 1668 次 A -> C
# 移动了 1669 次 A -> C
# 移动了 1670 次 A -> C
# 移动了 1671 次 A -> C
# 移动了 1672 次 A -> C
# 移动了 1673 次 A -> C
# 移动了 1674 次 A -> C
# 移动了 1675 次 A -> C
# 移动了 1676 次 A -> C
# 移动了 1677 次 A -> C
# 移动了 1678 次 A -> C
# 移动了 1679 次 A -> C
# 移动了 1680 次 A -> C
# 移动了 1681 次 A -> C
# 移动了 1682 次 A -> C
# 移动了 1683 次 A -> C
# 移动了 1684 次 A -> C
# 移动了 1685 次 A -> C
# 移动了 1686 次 A -> C
# 移动了 1687 次 A -> C
# 移动了 1688 次 A -> C
# 移动了 1689 次 A -> C
# 移动了 1690 次 A -> C
# 移动了 1691 次 A -> C
# 移动了 1692 次 A -> C
# 移动了 1693 次 A -> C
# 移动了 1694 次 A -> C
# 移动了 1695 次 A -> C
# 移动了 1696 次 A -> C
# 移动了 1697 次 A -> C
# 移动了 1698 次 A -> C
# 移动了 1699 次 A -> C
# 移动了 1700 次 A -> C
# 移动了 1701 次 A -> C
# 移动了 1702 次 A -> C
# 移动了 1703 次 A -> C
# 移动了 1704 次 A -> C
# 移动了 1705 次 A -> C
# 移动了 1706 次 A -> C
# 移动了 1707 次 A -> C
# 移动了 1708 次 A -> C
# 移动了 1709 次 A -> C
# 移动了 1710 次 A -> C
# 移动了 1711 次 A -> C
# 移动了 1712 次 A -> C
# 移动了 1713 次 A -> C
# 移动了 1714 次 A -> C
# 移动了 1715 次 A -> C
# 移动了 1716 次 A -> C
# 移动了 1717 次 A -> C
# 移动了 1718 次 A -> C
# 移动了 1719 次 A -> C
# 移动了 1720 次 A -> C
# 移动了 1721 次 A -> C
# 移动了 1722 次 A -> C
# 移动了 1723 次 A -> C
# 移动了 1724 次 A -> C
# 移动了 1725 次 A -> C
# 移动了 1726 次 A -> C
# 移动了 1727 次 A -> C
# 移动了 1728 次 A -> C
# 移动了 1729 次 A -> C
# 移动了 1730 次 A -> C
# 移动了 1731 次 A -> C
# 移动了 1732 次 A -> C
# 移动了 1733 次 A -> C
# 移动了 1734 次 A -> C
# 移动了 1735 次 A -> C
# 移动了 1736 次 A -> C
# 移动了 1737 次 A -> C
# 移动了 1738 次 A -> C
# 移动了 1739 次 A -> C
# 移动了 1740 次 A -> C
# 移动了 1741 次 A -> C
# 移动了 1742 次 A -> C
# 移动了 1743 次 A -> C
# 移动了 1744 次 A -> C
# 移动了 1745 次 A -> C
# 移动了 1746 次 A -> C
# 移动了 1747 次 A -> C
# 移动了 1748 次 A -> C
# 移动了 1749 次 A -> C
# 移动了 1750 次 A -> C
# 移动了 1751 次 A -> C
# 移动了 1752 次 A -> C
# 移动了 1753 次 A -> C
# 移动了 1754 次 A -> C
# 移动了 1755 次 A -> C
# 移动了 1756 次 A -> C
# 移动了 1757 次 A -> C
# 移动了 1758 次 A -> C
# 移动了 1759 次 A -> C
# 移动了 1760 次 A -> C
# 移动了 1761 次 A -> C
# 移动了 1762 次 A -> C
# 移动了 1763 次 A -> C
# 移动了 1764 次 A -> C
# 移动了 1765 次 A -> C
# 移动了 1766 次 A -> C
# 移动了 1767 次 A -> C
# 移动了 1768 次 A -> C
# 移动了 1769 次 A -> C
# 移动了 1770 次 A -> C
# 移动了 1771 次 A -> C
# 移动了 1772 次 A -> C
# 移动了 1773 次 A -> C
# 移动了 1774 次 A -> C
# 移动了 1775 次 A -> C
# 移动了 1776 次 A -> C
# 移动了 1777 次 A -> C
# 移动了 1778 次 A -> C
# 移动了 1779 次 A -> C
# 移动了 1780 次 A -> C
# 移动了 1781 次 A -> C
# 移动了 1782 次 A -> C
# 移动了 1783 次 A -> C
# 移动了 1784 次 A -> C
# 移动了 1785 次 A -> C
# 移动了 1786 次 A -> C
# 移动了 1787 次 A -> C
# 移动了 1788 次 A -> C
# 移动了 1789 次 A -> C
# 移动了 1790 次 A -> C
# 移动了 1791 次 A -> C
# 移动了 1792 次 A -> C
# 移动了 1793 次 A -> C
# 移动了 1794 次 A -> C
# 移动了 1795 次 A -> C
# 移动了 1796 次 A -> C
# 移动了 1797 次 A -> C
# 移动了 1798 次 A -> C
# 移动了 1799 次 A -> C
# 移动了 1800 次 A -> C
# 移动了 1801 次 A -> C
# 移动了 1802 次 A -> C
# 移动了 1803 次 A -> C
# 移动了 1804 次 A -> C
# 移动了 1805 次 A -> C
# 移动了 1806 次 A -> C
# 移动了 1807 次 A -> C
# 移动了 1808 次 A -> C
# 移动了 1809 次 A -> C
# 移动了 1810 次 A -> C
# 移动了 1811 次 A -> C
# 移动了 1812 次 A -> C
# 移动了 1813 次 A -> C
# 移动了 1814 次 A -> C
# 移动了 1815 次 A -> C
# 移动了 1816 次 A -> C
# 移动了 1817 次 A -> C
# 移动了 1818 次 A -> C
# 移动了 1819 次 A -> C
# 移动了 1820 次 A -> C
# 移动了 1821 次 A -> C
# 移动了 1822 次 A -> C
# 移动了 1823 次 A -> C
# 移动了 1824 次 A -> C
# 移动了 1825 次 A -> C
# 移动了 1826 次 A -> C
# 移动了 1827 次 A -> C
# 移动了 1828 次 A -> C
# 移动了 1829 次 A -> C
# 移动了 1830 次 A -> C
# 移动了 1831 次 A -> C
# 移动了 1832 次 A -> C
# 移动了 1833 次 A -> C
# 移动了 1834 次 A -> C
# 移动了 1835 次 A -> C
# 移动了 1836 次 A -> C
# 移动了 1837 次 A -> C
# 移动了 1838 次 A -> C
# 移动了 1839 次 A -> C
# 移动了 1840 次 A -> C
# 移动了 1841 次 A -> C
# 移动了 1842 次 A -> C
# 移动了 1843 次 A -> C
# 移动了 1844 次 A -> C
# 移动了 1845 次 A -> C
# 移动了 1846 次 A -> C
# 移动了 1847 次 A -> C
# 移动了 1848 次 A -> C
# 移动了 1849 次 A -> C
# 移动了 1850 次 A -> C
# 移动了 1851 次 A -> C
# 移动了 1852 次 A -> C
# 移动了 1853 次 A -> C
# 移动了 1854 次 A -> C
# 移动了 1855 次 A -> C
# 移动了 1856 次 A -> C
# 移动了 1857 次 A -> C
# 移动了 1858 次 A -> C
# 移动了 1859 次 A -> C
# 移动了 1860 次 A -> C
# 移动了 1861 次 A -> C
# 移动了 1862 次 A -> C
# 移动了 1863 次 A -> C
# 移动了 1864 次 A -> C
# 移动了 1865 次 A -> C
# 移动了 1866 次 A -> C
# 移动了 1867 次 A -> C
# 移动了 1868 次 A -> C
# 移动了 1869 次 A -> C
# 移动了 1870 次 A -> C
# 移动了 1871 次 A -> C
# 移动了 1872 次 A -> C
# 移动了 1873 次 A -> C
# 移动了 1874 次 A -> C
# 移动了 1875 次 A -> C
# 移动了 1876 次 A -> C
# 移动了 1877 次 A -> C
# 移动了 1878 次 A -> C
# 移动了 1879 次 A -> C
# 移动了 1880 次 A -> C
# 移动了 1881 次 A -> C
# 移动了 1882 次 A -> C
# 移动了 1883 次 A -> C
# 移动了 1884 次 A -> C
# 移动了 1885 次 A -> C
# 移动了 1886 次 A -> C
# 移动了 1887 次 A -> C
# 移动了 1888 次 A -> C
# 移动了 1889 次 A -> C
# 移动了 1890 次 A -> C
# 移动了 1891 次 A -> C
# 移动了 1892 次 A -> C
# 移动了 1893 次 A -> C
# 移动了 1894 次 A -> C
# 移动了 1895 次 A -> C
# 移动了 1896 次 A -> C
# 移动了 1897 次 A -> C
# 移动了 1898 次 A -> C
# 移动了 1899 次 A -> C
# 移动了 1900 次 A -> C
# 移动了 1901 次 A -> C
# 移动了 1902 次 A -> C
# 移动了 1903 次 A -> C
# 移动了 1904 次 A -> C
# 移动了 1905 次 A -> C
# 移动了 1906 次 A -> C
# 移动了 1907 次 A -> C
# 移动了 1908 次 A -> C
# 移动了 1909 次 A -> C
# 移动了 1910 次 A -> C
# 移动了 1911 次 A -> C
# 移动了 1912 次 A -> C
# 移动了 1913 次 A -> C
# 移动了 1914 次 A -> C
# 移动了 1915 次 A -> C
# 移动了 1916 次 A -> C
# 移动了 1917 次 A -> C
# 移动了 1918 次 A -> C
# 移动了 1919 次 A -> C
# 移动了 1920 次 A -> C
# 移动了 1921 次 A -> C
# 移动了 1922 次 A -> C
# 移动了 1923 次 A -> C
# 移动了 1924 次 A -> C
# 移动了 1925 次 A -> C
# 移动了 1926 次 A -> C
# 移动了 1927 次 A -> C
# 移动了 1928 次 A -> C
# 移动了 1929 次 A -> C
# 移动了 1930 次 A -> C
# 移动了 1931 次 A -> C
# 移动了 1932 次 A -> C
# 移动了 1933 次 A -> C
# 移动了 1934 次 A -> C
# 移动了 1935 次 A -> C
# 移动了 1936 次 A -> C
# 移动了 1937 次 A -> C
# 移动了 1938 次 A -> C
# 移动了 1939 次 A -> C
# 移动了 1940 次 A -> C
# 移动了 1941 次 A -> C
# 移动了 1942 次 A -> C
# 移动了 1943 次 A -> C
# 移动了 1944 次 A -> C
# 移动了 1945 次 A -> C
# 移动了 1946 次 A -> C
# 移动了 1947 次 A -> C
# 移动了 1948 次 A -> C
# 移动了 1949 次 A -> C
# 移动了 1950 次 A -> C
# 移动了 1951 次 A -> C
# 移动了 1952 次 A -> C
# 移动了 1953 次 A -> C
# 移动了 1954 次 A -> C
# 移动了 1955 次 A -> C
# 移动了 1956 次 A -> C
# 移动了 1957 次 A -> C
# 移动了 1958 次 A -> C
# 移动了 1959 次 A -> C
# 移动了 1960 次 A -> C
# 移动了 1961 次 A -> C
# 移动了 1962 次 A -> C
# 移动了 1963 次 A -> C
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-1-b3fa8bbe0966> in <module>()
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
# ---> 17 move(3,'A','B','C')
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      10     else:
#      11         # 把柱子A上的n-1个圆盘移动到B柱子上
# ---> 12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
#      14         move(n,a,b,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
# ...
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
# ---> 14         move(n,a,b,c)
#      15         # 把柱子B上的n-1个圆盘借助A移动到B上
#      16         move(n-1,b,a,c)
#
# ... last 1964 frames repeated, from the frame below ...
#
# <ipython-input-1-b3fa8bbe0966> in move(n, a, b, c)
#      10     else:
#      11         # 把柱子A上的n-1个圆盘移动到B柱子上
# ---> 12         move(n-1,a,c,b)
#      13         # 把柱子 A上最大的柱子移动到C上
#      14         move(n,a,b,c)
#
# RecursionError: maximum recursion depth exceeded in comparison
